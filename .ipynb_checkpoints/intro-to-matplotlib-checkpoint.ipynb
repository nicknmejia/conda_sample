# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4], [1,45,22,99]);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds axis
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1])
x = [1,2,3,4]
y = [2,4,3,7]
ax.plot(x,y)
plt.show()

# %%
#3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,y);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,2,3,4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x,y)

# 4. Customize plot
ax.set(title="Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show (you save the whole figure)

fig.savefig("./sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays

# %%
# Create some data
x = np.linspace(1,10,100)

# Plot the data
fig, ax = plt.subplots()
ax.plot(x,x**2)

# %%
# Use the same data to make a scatter plot
fix, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fix, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond butter": 10, "Peanut butter":8, "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Nick's Nut Butter Prices", xlabel="Nut Butters", ylabel="USD");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# Make some data for histograms and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for subplots

# %%
# Subplot option 1
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# Plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,5))

# Plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # Plotting from pandas DataFrames

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales.Price = car_sales.Price.replace('[\$\,]', '', regex=True).astype(float)
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White    150043      4   4000.0
# 1   Honda    Red     87899      4   5000.0
# 2  Toyota   Blue     32549      3   7000.0
# 3     BMW  Black     11179      5  22000.0
# 4  Nissan  White    213095      4   3500.0
# 5  Toyota  Green     99213      4   4500.0
# 6   Honda   Blue     45698      4   7500.0
# 7   Honda   Blue     54738      4   7000.0
# 8  Toyota  White     60000      4   6250.0
# 9  Nissan  White     31600      4   9700.0

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2023", periods=1000))

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Dos"] = pd.date_range("2/4/2023", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price        Dos
# 0  Toyota  White    150043      4   4000.0 2023-02-04
# 1   Honda    Red     87899      4   5000.0 2023-02-05
# 2  Toyota   Blue     32549      3   7000.0 2023-02-06
# 3     BMW  Black     11179      5  22000.0 2023-02-07
# 4  Nissan  White    213095      4   3500.0 2023-02-08
# 5  Toyota  Green     99213      4   4500.0 2023-02-09
# 6   Honda   Blue     45698      4   7500.0 2023-02-10
# 7   Honda   Blue     54738      4   7000.0 2023-02-11
# 8  Toyota  White     60000      4   6250.0 2023-02-12
# 9  Nissan  White     31600      4   9700.0 2023-02-13

# %%
car_sales["Total"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price        Dos    Total
# 0  Toyota  White    150043      4   4000.0 2023-02-04   4000.0
# 1   Honda    Red     87899      4   5000.0 2023-02-05   9000.0
# 2  Toyota   Blue     32549      3   7000.0 2023-02-06  16000.0
# 3     BMW  Black     11179      5  22000.0 2023-02-07  38000.0
# 4  Nissan  White    213095      4   3500.0 2023-02-08  41500.0
# 5  Toyota  Green     99213      4   4500.0 2023-02-09  46000.0
# 6   Honda   Blue     45698      4   7500.0 2023-02-10  53500.0
# 7   Honda   Blue     54738      4   7000.0 2023-02-11  60500.0
# 8  Toyota  White     60000      4   6250.0 2023-02-12  66750.0
# 9  Nissan  White     31600      4   9700.0 2023-02-13  76450.0

# %%
# Let's plot the total sales
car_sales.plot(x="Dos", y="Total");

# %%
car_sales.plot(x="Odometer", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer', ylabel='Price'>

# %%
car_sales.plot(x="Make", y="Price", kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales.plot.bar();

# %%
car_sales.plot(x="Make", y="Odometer", kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
# How about histograms?
car_sales.Odometer.plot.hist(bins=20);

# %%
# Let's try on another dataset
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age
heart_disease.age.plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### Which one should you use?  (pyplot vs matplotlib OO method?)
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method
over_50.plot(kind="scatter", x="age", y="chol", c='target');

# %%
# OO method
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter', x='age', y='chol', c='target', ax=ax);
ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50.age, y=over_50.chol, c=over_50.target);

ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");

ax.legend(*scatter.legend_elements(), title="Target");
ax.axhline(over_50.chol.mean(), linestyle="--")

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
plt.style.use("seaborn-whitegrid")
# Subplots of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10))
# Add data to ax 0
scatter = ax0.scatter(x=over_50.age,
                      y=over_50.chol,
                      c=over_50.target,
                      cmap="winter")

scatter2 = ax1.scatter(x=over_50.age,
                       y=over_50.thalach,
                       c=over_50.target,
                       cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol")
ax0.set_xlim([50,80])
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(y=over_50.chol.mean(), linestyle="--", c="r")

ax1.set(title="Heart Disease and Heart Rate",
        xlabel="Age",
        ylabel="Heart Rate")
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
ax1.legend(*scatter2.legend_elements(), title="Target")
ax1.axhline(y=over_50.thalach.mean(), linestyle="--", c="r")

# Add a title to the figure
fig.suptitle("Heart Disease Shizz", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Shizz')

# %% [markdown]
# # Customizing Matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.Price.plot();

# %%
plt.style.use("ggplot")

# %%
car_sales.Price.plot()
# Out:
# <AxesSubplot:>

# %%
fig.savefig("figure-pic")
